# %%
from transformers import pipeline

checkpoint = "openai/clip-vit-large-patch14"
detector = pipeline(model=checkpoint, task="zero-shot-image-classification")
#checkpoint = "google/siglip-so400m-patch14-384"
#detector = pipeline(task="zero-shot-image-classification", model="google/siglip-so400m-patch14-384")
# Out:
# WARNING:tensorflow:From C:\Users\tshed\AppData\Roaming\Python\Python312\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
# model.safetensors:   0%|          | 0.00/1.71G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/905 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/961k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/525k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.22M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/389 [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/316 [00:00<?, ?B/s]
# Using a slow image processor as `use_fast` is unset and a slow processor was saved with this model. `use_fast=True` will be the default behavior in v4.52, even if the model was saved with a slow processor. This will result in minor differences in outputs. You'll still be able to use a slow processor with `use_fast=False`.
# Device set to use cpu

# %%
from datasets import load_dataset

dataset = load_dataset('pcuenq/oxford-pets')
dataset
# Out:
# README.md:   0%|          | 0.00/565 [00:00<?, ?B/s]
# C:\Users\tshed\AppData\Roaming\Python\Python312\site-packages\huggingface_hub\file_download.py:142: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\tshed\.cache\huggingface\hub\datasets--pcuenq--oxford-pets. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# dataset_infos.json:   0%|          | 0.00/1.10k [00:00<?, ?B/s]
# (…)-00000-of-00001-ecc2afb43dedd5e0.parquet:   0%|          | 0.00/234M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/7390 [00:00<?, ? examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['path', 'label', 'dog', 'image'],
#         num_rows: 7390
#     })
# })

# %%
dataset['train'][0]['image']
# Out:
# {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00\xff\xdb\x00C\x00\x08\x06\x06\x07\x06\x05\x08\x07\x07\x07\t\t\x08\n\x0c\x14\r\x0c\x0b\x0b\x0c\x19\x12\x13\x0f\x14\x1d\x1a\x1f\x1e\x1d\x1a\x1c\x1c $.\' ",#\x1c\x1c(7),01444\x1f\'9=82<.342\xff\xdb\x00C\x01\t\t\t\x0c\x0b\x0c\x18\r\r\x182!\x1c!22222222222222222222222222222222222222222222222222\xff\xc0\x00\x11\x08\x01\xf4\x01Y\x03\x01"\x00\x02\x11\x01\x03\x11\x01\xff\xc4\x00\x1f\x00\x00\x01\x05\x01\x01\x01\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x01\x02\x03\x04\x05\x06\x07\x08\t\n\x0b\xff\xc4\x00\xb5\x10\x00\x02\x01\x03\x03\x02\x04\x03\x05\x05\x04\x04\x00\x00\x01}\x01\x02\x03\x00\x04\x11\x05\x12!1A\x06\x13Qa\x07"q\x142\x81\x91\xa1\x08#B\xb1\xc1\x15R\xd1\xf0$3br\x82\t\n\x16\x17\x18\x19\x1a%&\'()*456789:CDEFGHIJSTUVWXYZcdefghijstuvwxyz\t\n\x0b\xff\xc4\x00\xb5\x11\x00\x02\x01\x02\x04\x04\x03\x04\x07\x05\x04\x04\x00\x01\x02w\x00\x01\x02\x03\x11\x04\x05!1\x06\x12AQ\x07aq\x13"2\x81\x08\x14B\x91\xa1\xb1\xc1\t#3R\xf0\x15br\xd1\n\x16$4\xe1%\xf1\x17\x18\x19\x1a&\'()*56789:CDEFGHIJSTUVWXYZcdefghijstuvwxyz?\x00\xe0fT*d@VU\xe9\x8e\xf5X;;o\xf2\x1cm\xe2A\x8e\x9d?\xcf\xe1W\x96)w`\xa8\xc7\xaei|\x89\x83\x16P\xbe\x84\x16\xea+\xcf\x89\xc8\xecg\xcb\xb9\x8f\x99\xbb\x0b\xd0\x0cu\xf4\xa8\xcc\xe3p]\x87i\x07\x91\xc15vM2V\x90\xed#\xcb\xe9\x8c\xe0\xe2\x94Y\xca\x8c1\x18\xc19\xce\xe1\xc1\xef\xc5_2\xb0]\x19\xa0\x15`\xccNs\x83\xefB\x08\xc4\x8e\x14\xae\x00<\x93V\xe7\xb4\x98\x1c\xaa9\xfasT\x9a6C\xca2\xfdE+\xa6ZcX\xa6\xec\xa0\x04\xf74\xc7\x19m\xc0\x11\x91D\x98q\x90O\x07\xaei\xa7\x94^O\xa7\x18\xad\x00H\x0826\x7f<\xd4\x92\x02\x01\x04\x0eO~\xd5\n\xe1d\xe5\xb1\x91\xd4\x1cq\xf5\xabS\x04e\x04s\xef\x93\xfc\xe91\xf5\x14\x8c\xc42\xa0\x0cp\t\xebPIi\x1d\xd4{\\`\x8e\x8c;U\xa8\x904\x07\xd7\xb6)\xb1\x1d\xb9\xce1\xd8\x8aI\xd9\x893\x9d\xb9\xb5\x92\xd5\xf6H>\x8c:\x1a\x9e\xc2\x7f(\x94#\x86<\x1e\xd9\xe9[\xd3A\x1c\xd1\x95u\xdc\xa7\xf4\xfaV\x15\xdd\xb4\x96r\xa9\xfb\xd1\xe7*\xd8\xce~\xb5\xaa\x976\x8c\xd3}\x19vI\x92\',\xc2B\xa78h\xeb!\xdbs\xb3\x13\xb8\x93\xc9\xc7Z\xd0\xb6\x9e)\x7fw#\xb0c\x8c1\xf5<\x1f\xd4\x8a\xa1 a#\x07\xe1\x81\xc1\xcf\x1c\xf7\xa2\n\xda\x02\xd0nH\x1c\x1e\xb5$\xb3\t\x95X\xff\x00\xac\x03i?\xde\x1d\x8f\xd6\xa1\xc8\xfa\xd0\\\x8e\x9c}*\xecU\x89\x15\x18\x9es\xf9V\x8d\xa1Xlo\\t(#>\xf9\xedY9f rs\xd0z\xd6\x9e\xa6\x89eiof\xaf\x97\xc6\xf9\xb1\xfd\xf3\xfe@\xfc3\xde\x93]\x06\x91]Us\xfe\xb2?\xfb\xea\xa6D\xee\x08o\xf7Nk41\xecqO\x19\x14\xdcI\xb1\xaa$\xdb\xc7qVb\xbe(\x08e\r\xf5\xacU\x9eE\x1f{p\xf4a\x9a\x94\\\x8f\xe2L\x7f\xbak7\x0b\x8a\xc6\xbc\xd7\xa2U<c>\x95X\x90\xd9\xf5\xaa\x8b:\x1e\x04\x83\xe8\xc3\x152\xb0a\xf7\x94\xfd\x1a\x92V\x15\x81\x94\x9e\xf5\x13G\x9ejG\xe9\xfe\xb3\xf5\xaa\xef\xd7\x1b\xf3V\x16\x10\x80:\x9aau\x14\x9bs\xd2\x8d\xa3\x9c\x9e\x9e\xd4\xc6Kj\xd9\xba\x8c\x01\x8f\x98\x1e\x99\xae\x95p1\xb8\x92z\x15A\xcf_Z\xe7-\xd5\xd1\x84\xaa\x8c\x14\x1e\x1c\x03\xd7\xeb[p\xdd\xefPT"\x93\xd4\xf78\x1e\xbf\xe3XV\x8f3E%r\xf8\xb1\x86y\x04\x8f\x0cD\xe3\x00\xc87\x91\xf8\x1e?JSeo\x83\xf2\xa0\'\xa8X\xd7\xfc)\x9ekya\xe3\'\xee\x903\xdc\xf68\xa8\xdayL\xd8H\xc8\x88\x90\xc8\xfb\x8f\xdd=1\xc0\xf49\x1c\xd4F6\x1f-\xc8\xa7\xd2m\\\x00R.\x07\x1f.\xdc~U\x95u\xa3*\xf3\x11+\xecNEnH\xe3h\x03\xa7P\rA\'9=>\x95Q\x9b[2.\xceZD\x96\xdd\xf6\xb0#\xf5\x06\x93+ \xe4\x00k\xa0\xbb\xb7\x8d\xcb&D\x89\xd9\xb6\xed\x ...
#  'path': None}

# %%
from PIL import Image
import io
from tqdm import tqdm

labels_oxford_pets = ['Siamese', 'Birman', 'shiba inu', 'staffordshire bull terrier', 'basset hound', 'Bombay', 'japanese chin', 'chihuahua', 'german shorthaired', 'pomeranian', 'beagle', 'english cocker spaniel', 'american pit bull terrier', 'Ragdoll', 'Persian', 'Egyptian Mau', 'miniature pinscher', 'Sphynx', 'Maine Coon', 'keeshond', 'yorkshire terrier', 'havanese', 'leonberger', 'wheaten terrier', 'american bulldog', 'english setter', 'boxer', 'newfoundland', 'Bengal', 'samoyed', 'British Shorthair', 'great pyrenees', 'Abyssinian', 'pug', 'saint bernard', 'Russian Blue', 'scottish terrier']

# List to store true labels and predicted labels
true_labels = []
predicted_labels = []

# %%
for i in tqdm(range(len(dataset['train']))):
    # Get the image bytes from the dataset
    image_bytes = dataset['train'][i]['image']['bytes']
    
    # Convert the bytes to a PIL image
    image = Image.open(io.BytesIO(image_bytes))
    
    # Run the detector on the image with the provided labels
    results = detector(image, candidate_labels=labels_oxford_pets)
    # Sort the results by score in descending order
    sorted_results = sorted(results, key=lambda x: x['score'], reverse=True)
    
    # Get the top predicted label
    predicted_label = sorted_results[0]['label']
    
    # Append the true and predicted labels to the respective lists
    true_labels.append(dataset['train'][i]['label'])
    predicted_labels.append(predicted_label)
# Out:
#   3%|▎         | 230/7390 [05:30<2:51:35,  1.44s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 9
#       6 image = Image.open(io.BytesIO(image_bytes))
#       8 # Run the detector on the image with the provided labels
# ----> 9 results = detector(image, candidate_labels=labels_oxford_pets)
#      10 # Sort the results by score in descending order
#      11 sorted_results = sorted(results, key=lambda x: x['score'], reverse=True)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\transformers\pipelines\zero_shot_image_classification.py:113, in ZeroShotImageClassificationPipeline.__call__(self, image, **kwargs)
#     111 if image is None:
#     112     raise ValueError("Cannot call the zero-shot-image-classification pipeline without an images argument!")
# --> 113 return super().__call__(image, **kwargs)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\transformers\pipelines\base.py:1371, in Pipeline.__call__(self, inputs, num_workers, batch_size, *args, **kwargs)
#    1363     return next(
#    1364         iter(
#    1365             self.get_iterator(
#    (...)
#    1368         )
#    1369     )
#    1370 else:
# -> 1371     return self.run_single(inputs, preprocess_params, forward_params, postprocess_params)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\transformers\pipelines\base.py:1378, in Pipeline.run_single(self, inputs, preprocess_params, forward_params, postprocess_params)
#    1376 def run_single(self, inputs, preprocess_params, forward_params, postprocess_params):
#    1377     model_inputs = self.preprocess(inputs, **preprocess_params)
# -> 1378     model_outputs = self.forward(model_inputs, **forward_params)
#    1379     outputs = self.postprocess(model_outputs, **postprocess_params)
#    1380     return outputs
#
# File ~\AppData\Roaming\Python\Python312\site-packages\transformers\pipelines\base.py:1278, in Pipeline.forward(self, model_inputs, **forward_params)
#    1276     with inference_context():
#    1277         model_inputs = self._ensure_tensor_on_device(model_inputs, device=self.device)
# -> 1278         model_outputs = self._forward(model_inputs, **forward_params)
#    1279         model_outputs = self._ensure_tensor_on_device(model_outputs, device=torch.device("cpu"))
#    1280 else:
#
# File ~\AppData\Roaming\Python\Python312\site-packages\transformers\pipelines\zero_shot_image_classification.py:165, in ZeroShotImageClassificationPipeline._forward(self, model_inputs)
#     161 else:
#     162     # Batching case.
#     163     text_inputs = text_inputs[0][0]
# --> 165 outputs = self.model(**text_inputs, **model_inputs)
#     167 model_outputs = {
#     168     "candidate_labels": candidate_labels,
#     169     "logits": outputs.logits_per_image,
#     170 }
#     171 return model_outputs
#
# File ~\AppData\Roaming\Python\Python312\site-packages\torch\nn\modules\module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\torch\nn\modules\module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~\AppData\Roaming\Python\Python312\site-packages\transformers\models\clip\modeling_clip.py:1369, in CLIPModel.forward(self, input_ids, pixel_values, attention_mask, position_ids, return_loss, output_attentions, output_hidden_states, interpolate_pos_encoding, return_dict)
#    1364 output_hidden_states = (
#    1365     output_hidden_states if output_hidden_states is not None else self.config.output_hidden_states
#    1366 )
#    1367 return_dict = return_dict if return_dict is not None else self.config.use_return_dict
# -> 1369 vision_outputs = self.vision_model(
#    1370     pixel_values=pixel_values,
#    1371     output_attentions=output_attentions,
#    1372     output_hidden_states=output_hidden_states,
#    1373     interpolate_pos_encoding=interpolate_pos_encoding,
#    1374     return_dict=return_dict,
#    1375 )
#    1377 text_outputs = self.text_model(
#    1378     input_ids=input_ids,
#    1379     attention_mask=attention_mask,
#    (...)
#    1383     return_dict=return_dict,
#    1384 )
#    1386 image_embeds = vision_outputs[1]
#
# File ~\AppData\Roaming\Python\Python312\site-packages\torch\nn\modules\module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\torch\nn\modules\module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~\AppData\Roaming\Python\Python312\site-packages\transformers\models\clip\modeling_clip.py:1103, in CLIPVisionTransformer.forward(self, pixel_values, output_attentions, output_hidden_states, return_dict, interpolate_pos_encoding)
#    1100 hidden_states = self.embeddings(pixel_values, interpolate_pos_encoding=interpolate_pos_encoding)
#    1101 hidden_states = self.pre_layrnorm(hidden_states)
# -> 1103 encoder_outputs = self.encoder(
#    1104     inputs_embeds=hidden_states,
#    1105     output_attentions=output_attentions,
#    1106     output_hidden_states=output_hidden_states,
#    1107     return_dict=return_dict,
#    1108 )
#    1110 last_hidden_state = encoder_outputs[0]
#    1111 pooled_output = last_hidden_state[:, 0, :]
#
# File ~\AppData\Roaming\Python\Python312\site-packages\torch\nn\modules\module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\torch\nn\modules\module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~\AppData\Roaming\Python\Python312\site-packages\transformers\models\clip\modeling_clip.py:883, in CLIPEncoder.forward(self, inputs_embeds, attention_mask, causal_attention_mask, output_attentions, output_hidden_states, return_dict)
#     875     layer_outputs = self._gradient_checkpointing_func(
#     876         encoder_layer.__call__,
#     877         hidden_states,
#    (...)
#     880         output_attentions,
#     881     )
#     882 else:
# --> 883     layer_outputs = encoder_layer(
#     884         hidden_states,
#     885         attention_mask,
#     886         causal_attention_mask,
#     887         output_attentions=output_attentions,
#     888     )
#     890 hidden_states = layer_outputs[0]
#     892 if output_attentions:
#
# File ~\AppData\Roaming\Python\Python312\site-packages\torch\nn\modules\module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\torch\nn\modules\module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~\AppData\Roaming\Python\Python312\site-packages\transformers\models\clip\modeling_clip.py:614, in CLIPEncoderLayer.forward(self, hidden_states, attention_mask, causal_attention_mask, output_attentions)
#     611 residual = hidden_states
#     613 hidden_states = self.layer_norm1(hidden_states)
# --> 614 hidden_states, attn_weights = self.self_attn(
#     615     hidden_states=hidden_states,
#     616     attention_mask=attention_mask,
#     617     causal_attention_mask=causal_attention_mask,
#     618     output_attentions=output_attentions,
#     619 )
#     620 hidden_states = residual + hidden_states
#     622 residual = hidden_states
#
# File ~\AppData\Roaming\Python\Python312\site-packages\torch\nn\modules\module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\torch\nn\modules\module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~\AppData\Roaming\Python\Python312\site-packages\transformers\models\clip\modeling_clip.py:532, in CLIPSdpaAttention.forward(self, hidden_states, attention_mask, causal_attention_mask, output_attentions)
#     530 query_states = self.q_proj(hidden_states)
#     531 key_states = self.k_proj(hidden_states)
# --> 532 value_states = self.v_proj(hidden_states)
#     534 query_states = query_states.view(bsz, -1, self.num_heads, self.head_dim).transpose(1, 2)
#     535 key_states = key_states.view(bsz, -1, self.num_heads, self.head_dim).transpose(1, 2)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\torch\nn\modules\module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\torch\nn\modules\module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~\AppData\Roaming\Python\Python312\site-packages\torch\nn\modules\linear.py:125, in Linear.forward(self, input)
#     124 def forward(self, input: Tensor) -> Tensor:
# --> 125     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score

# Calculate accuracy
accuracy = accuracy_score(true_labels, predicted_labels)

# Calculate precision and recall
precision = precision_score(true_labels, predicted_labels, average='weighted', labels=labels_oxford_pets)
recall = recall_score(true_labels, predicted_labels, average='weighted', labels=labels_oxford_pets)

# Print the results
print(f"Accuracy: {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")

# %% [markdown]
# ## Gradio example

# %%
import gradio as gr
from transformers import pipeline

# Load models
vit_classifier = pipeline("image-classification", model="kuhs/vit-base-oxford-iiit-pets")
clip_detector = pipeline(model="openai/clip-vit-large-patch14", task="zero-shot-image-classification")

labels_oxford_pets = [
    'Siamese', 'Birman', 'shiba inu', 'staffordshire bull terrier', 'basset hound', 'Bombay', 'japanese chin',
    'chihuahua', 'german shorthaired', 'pomeranian', 'beagle', 'english cocker spaniel', 'american pit bull terrier',
    'Ragdoll', 'Persian', 'Egyptian Mau', 'miniature pinscher', 'Sphynx', 'Maine Coon', 'keeshond', 'yorkshire terrier',
    'havanese', 'leonberger', 'wheaten terrier', 'american bulldog', 'english setter', 'boxer', 'newfoundland', 'Bengal',
    'samoyed', 'British Shorthair', 'great pyrenees', 'Abyssinian', 'pug', 'saint bernard', 'Russian Blue', 'scottish terrier'
]

def classify_pet(image):
    vit_results = vit_classifier(image)
    vit_output = {result['label']: result['score'] for result in vit_results}
    
    clip_results = clip_detector(image, candidate_labels=labels_oxford_pets)
    clip_output = {result['label']: result['score'] for result in clip_results}
    
    return {"ViT Classification": vit_output, "CLIP Zero-Shot Classification": clip_output}

example_images = [
    ["example_images/dog1.jpeg"],
    ["example_images/dog2.jpeg"],
    ["example_images/leonberger.jpg"],
    ["example_images/snow_leopard.jpeg"],
    ["example_images/cat.jpg"]
]

iface = gr.Interface(
    fn=classify_pet,
    inputs=gr.Image(type="filepath"),
    outputs=gr.JSON(),
    title="Pet Classification Comparison",
    description="Upload an image of a pet, and compare results from a trained ViT model and a zero-shot CLIP model.",
    examples=example_images
)

iface.launch()
